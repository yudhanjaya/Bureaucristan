# %% [markdown]
# This is a local version of CaptainValor's adaptation of  https://github.com/ak9250/gpt-2-colab.
# Uses nshepperd's gpt-2 fork, which allows tuning the OpenAI GPT-2 model with your own data.

# %%
#Dependencies: uncomment and run if needed
#!pip3 install --upgrade tensorflow-gpu
#!pip3 install --upgrade tqdm #progress bar; model.py requires it
#Also see https://github.com/nshepperd/gpt-2/blob/finetuning/requirements.txt

# %%
cd gpt2-finetuning/
# Out:
# [Errno 2] No such file or directory: 'gpt2-finetuning/'
# /home/manifold/MechanicalTennyson/gpt2-finetuning

# %%
# !python3 download_model.py 117M #this downloads one 498M file. 
#Once done, gpt2-finetuning -> models -> 117M is where all the stuff is. Check.

# %%
# !export PYTHONIOENCODING=UTF-8

# %%
# !PYTHONPATH=src ./train.py --dataset ./data/Tang-320-poems.txt --save_every 100
# Out:
# 2019-04-16 14:47:35.877386: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2019-04-16 14:47:36.316961: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x3646af0 executing computations on platform CUDA. Devices:
# 2019-04-16 14:47:36.316993: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2019-04-16 14:47:36.317000: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2019-04-16 14:47:36.336409: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3500000000 Hz
# 2019-04-16 14:47:36.337149: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x4195c00 executing computations on platform Host. Devices:
# ...

# %%
# !cp -r ./checkpoint/run1/* ./models/117M

# %%
# !python3 ./src/generate_unconditional_samples.py
# Out:
# 2019-04-17 14:56:03.710231: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2019-04-17 14:56:04.064783: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x259ebd0 executing computations on platform CUDA. Devices:
# 2019-04-17 14:56:04.064833: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# 2019-04-17 14:56:04.064849: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (1): GeForce GTX 1080 Ti, Compute Capability 6.1
# 2019-04-17 14:56:04.088440: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3500000000 Hz
# 2019-04-17 14:56:04.089462: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1280ef0 executing computations on platform Host. Devices:
# ...
